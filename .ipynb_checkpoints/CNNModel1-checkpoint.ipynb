# %%
#importing the libraries
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model, Sequential #creating the architecture for the CNN
from keras.layers import Dense, Conv2D, Flatten #creating layers for the model
import numpy as np
import os #to access the data stored in the computer
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
import numpy as np # linear algebra
#import random
# data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2
import random
import shutil
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#import shutil
from glob import glob
# Helper libraries
import matplotlib.pyplot as plt
#import math
# %matplotlib inline
#print(tf.__version__)
# Out:
# WARNING:tensorflow:From C:\Users\Satwi\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
data_root='C:/Users/Satwi/Downloads/finger liveness python/finger liveness python/datasets'
path_unauthenticate_image = os.path.join('C:/Users/Satwi/Downloads/finger liveness python/finger liveness python/datasets/unauthenticate')
path_authenticate_image = os.path.join('C:/Users/Satwi/Downloads/finger liveness python/finger liveness python/datasets/authenticate')

# %%
unauthenticate_images_ls = glob(os.path.join(path_unauthenticate_image,"*.jpeg"))

authenticate_images_ls = glob(os.path.join(path_authenticate_image,"*.jpeg"))
authenticate_images_ls.extend(glob(os.path.join(path_authenticate_image,"*.jpeg")))

# %%
image_unauthenticate = cv2.imread(os.path.join(unauthenticate_images_ls[1]))
image_authenticate = cv2.imread(os.path.join(authenticate_images_ls[5]))
operatedImage = cv2.cvtColor(image_authenticate, cv2.COLOR_BGR2GRAY)

# modify the data type
# setting to 32-bit floating point
operatedImage = np.float32(operatedImage)

# apply the cv2.cornerHarris method
# to detect the corners with appropriate
# values as input parameters
dest = cv2.cornerHarris(operatedImage, 2, 5, 0.07)

f = plt.figure(figsize=(8, 8))
f.add_subplot(1, 2, 1)
plt.imshow(image_authenticate)
f.add_subplot(1,2, 2)
plt.imshow(image_unauthenticate)

# %%
total_train_unauthenticate = len(os.listdir('C:/Users/Satwi/Downloads/finger liveness python/finger liveness python/datasets/train/unauthenticate'))
total_train_authenticate = len(os.listdir('C:/Users/Satwi/Downloads/finger liveness python/finger liveness python/datasets/train/authenticate'))
total_test_unauthenticate = len(os.listdir('C:/Users/Satwi/Downloads/finger liveness python/finger liveness python/datasets/test/unauthenticate'))
total_test_authenticate = len(os.listdir('C:/Users/Satwi/Downloads/finger liveness python/finger liveness python/datasets/test/authenticate'))

print("Train sets images unauthenticate: {}".format(total_train_unauthenticate))
print("Train sets images healthy: {}".format(total_train_authenticate))
print("Test sets images unauthenticate: {}".format(total_test_unauthenticate))
print("Test sets images authenticate: {}".format(total_test_authenticate))
# Out:
# Train sets images unauthenticate: 29
# Train sets images healthy: 24
# Test sets images unauthenticate: 29
# Test sets images authenticate: 24

# %%
batch_size =15
epochs = 50
IMG_HEIGHT = 150
IMG_WIDTH = 150
train_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our training data
test_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our validation data

# %%
train_dir = os.path.join('C:/Users/Satwi/Downloads/finger liveness python/finger liveness python/datasets/train')
test_dir = os.path.join('C:/Users/Satwi/Downloads/finger liveness python/finger liveness python/datasets/test')


total_train = total_train_authenticate + total_train_unauthenticate
total_test = total_test_authenticate + total_test_unauthenticate

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                           class_mode='binary')
test_data_gen = test_image_generator.flow_from_directory(batch_size=batch_size,
                                                              directory=test_dir,
                                                              target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                              class_mode='binary')
# Out:
# Found 53 images belonging to 2 classes.
# Found 53 images belonging to 2 classes.

# %%
model = Sequential([
    Conv2D(32, 3, padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH ,3)),
    MaxPooling2D(2, 2),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1)

])
# Out:
# WARNING:tensorflow:From C:\Users\Satwi\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Satwi\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Satwi\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 75, 75, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 37, 37, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 18, 18, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 20736)             0
#
#  dense (Dense)               (None, 512)               10617344
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 10674177 (40.72 MB)
# Trainable params: 10674177 (40.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(
    train_data_gen,
    steps_per_epoch=total_train // batch_size,
    epochs=epochs,
    validation_data=test_data_gen,
    validation_steps=total_test // batch_size
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Satwi\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Satwi\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - 5s 776ms/step - loss: 1.8682 - accuracy: 0.4222 - val_loss: 0.8965 - val_accuracy: 0.4444
# Epoch 2/50
# 3/3 [==============================] - 1s 384ms/step - loss: 0.8218 - accuracy: 0.4667 - val_loss: 0.6823 - val_accuracy: 0.4889
# Epoch 3/50
# 3/3 [==============================] - 1s 373ms/step - loss: 0.6942 - accuracy: 0.4474 - val_loss: 0.6788 - val_accuracy: 0.4444
# Epoch 4/50
# 3/3 [==============================] - 1s 387ms/step - loss: 0.6820 - accuracy: 0.4444 - val_loss: 0.6518 - val_accuracy: 0.3778
# Epoch 5/50
# 3/3 [==============================] - 1s 406ms/step - loss: 0.6501 - accuracy: 0.4889 - val_loss: 0.6219 - val_accuracy: 0.4889
# Epoch 6/50
# 3/3 [==============================] - 1s 370ms/step - loss: 0.5680 - accuracy: 0.6053 - val_loss: 0.6306 - val_accuracy: 0.6222
# Epoch 7/50
# 3/3 [==============================] - 1s 382ms/step - loss: 0.6032 - accuracy: 0.6444 - val_loss: 0.5601 - val_accuracy: 0.6889
# Epoch 8/50
# 3/3 [==============================] - 1s 369ms/step - loss: 0.5699 - accuracy: 0.6579 - val_loss: 0.5495 - val_accuracy: 0.6889
# Epoch 9/50
# 3/3 [==============================] - 1s 420ms/step - loss: 0.5604 - accuracy: 0.5556 - val_loss: 0.5522 - val_accuracy: 0.6889
# Epoch 10/50
# 3/3 [==============================] - 1s 404ms/step - loss: 0.5620 - accuracy: 0.6842 - val_loss: 0.5405 - val_accuracy: 0.7111
# Epoch 11/50
# 3/3 [==============================] - 1s 370ms/step - loss: 0.5277 - accuracy: 0.7368 - val_loss: 0.5277 - val_accuracy: 0.6889
# Epoch 12/50
# 3/3 [==============================] - 1s 370ms/step - loss: 0.5227 - accuracy: 0.6444 - val_loss: 0.4826 - val_accuracy: 0.7111
# Epoch 13/50
# 3/3 [==============================] - 1s 392ms/step - loss: 0.4836 - accuracy: 0.7632 - val_loss: 0.4515 - val_accuracy: 0.7333
# Epoch 14/50
# 3/3 [==============================] - 1s 338ms/step - loss: 0.4142 - accuracy: 0.7368 - val_loss: 0.4539 - val_accuracy: 0.7111
# Epoch 15/50
# 3/3 [==============================] - 1s 376ms/step - loss: 0.3825 - accuracy: 0.8000 - val_loss: 0.4200 - val_accuracy: 0.8000
# Epoch 16/50
# 3/3 [==============================] - 1s 335ms/step - loss: 0.3599 - accuracy: 0.8158 - val_loss: 0.5095 - val_accuracy: 0.7556
# Epoch 17/50
# 3/3 [==============================] - 1s 411ms/step - loss: 0.5009 - accuracy: 0.6889 - val_loss: 0.4266 - val_accuracy: 0.7333
# Epoch 18/50
# 3/3 [==============================] - 1s 384ms/step - loss: 0.4358 - accuracy: 0.7105 - val_loss: 0.4429 - val_accuracy: 0.7111
# Epoch 19/50
# 3/3 [==============================] - 1s 369ms/step - loss: 0.4223 - accuracy: 0.7632 - val_loss: 0.4080 - val_accuracy: 0.7556
# Epoch 20/50
# 3/3 [==============================] - 1s 384ms/step - loss: 0.4007 - accuracy: 0.7895 - val_loss: 0.3620 - val_accuracy: 0.7778
# Epoch 21/50
# 3/3 [==============================] - 1s 326ms/step - loss: 0.3727 - accuracy: 0.8158 - val_loss: 0.3642 - val_accuracy: 0.7556
# Epoch 22/50
# 3/3 [==============================] - 1s 371ms/step - loss: 0.4101 - accuracy: 0.7632 - val_loss: 0.3844 - val_accuracy: 0.7778
# Epoch 23/50
# 3/3 [==============================] - 1s 344ms/step - loss: 0.3957 - accuracy: 0.7632 - val_loss: 0.3742 - val_accuracy: 0.7556
# Epoch 24/50
# 3/3 [==============================] - 1s 357ms/step - loss: 0.4453 - accuracy: 0.7895 - val_loss: 0.3964 - val_accuracy: 0.8000
# Epoch 25/50
# 3/3 [==============================] - 1s 369ms/step - loss: 0.3812 - accuracy: 0.8000 - val_loss: 0.3708 - val_accuracy: 0.7778
# Epoch 26/50
# 3/3 [==============================] - 1s 379ms/step - loss: 0.3948 - accuracy: 0.7778 - val_loss: 0.3329 - val_accuracy: 0.8000
# Epoch 27/50
# 3/3 [==============================] - 1s 370ms/step - loss: 0.4360 - accuracy: 0.8000 - val_loss: 0.3912 - val_accuracy: 0.7556
# Epoch 28/50
# 3/3 [==============================] - 1s 356ms/step - loss: 0.3231 - accuracy: 0.8158 - val_loss: 0.3527 - val_accuracy: 0.7556
# Epoch 29/50
# 3/3 [==============================] - 1s 369ms/step - loss: 0.3854 - accuracy: 0.7632 - val_loss: 0.3678 - val_accuracy: 0.7778
# Epoch 30/50
# 3/3 [==============================] - 1s 349ms/step - loss: 0.3632 - accuracy: 0.7895 - val_loss: 0.3212 - val_accuracy: 0.7556
# Epoch 31/50
# 3/3 [==============================] - 1s 331ms/step - loss: 0.3030 - accuracy: 0.7895 - val_loss: 0.3421 - val_accuracy: 0.7556
# Epoch 32/50
# 3/3 [==============================] - 1s 349ms/step - loss: 0.3210 - accuracy: 0.7632 - val_loss: 0.3849 - val_accuracy: 0.7556
# Epoch 33/50
# 3/3 [==============================] - 1s 334ms/step - loss: 0.3628 - accuracy: 0.8158 - val_loss: 0.4011 - val_accuracy: 0.7778
# Epoch 34/50
# 3/3 [==============================] - 1s 351ms/step - loss: 0.4402 - accuracy: 0.7368 - val_loss: 0.3605 - val_accuracy: 0.8000
# Epoch 35/50
# 3/3 [==============================] - 1s 332ms/step - loss: 0.3575 - accuracy: 0.7895 - val_loss: 0.3788 - val_accuracy: 0.7333
# Epoch 36/50
# 3/3 [==============================] - 1s 392ms/step - loss: 0.3899 - accuracy: 0.7632 - val_loss: 0.3879 - val_accuracy: 0.7556
# Epoch 37/50
# 3/3 [==============================] - 1s 330ms/step - loss: 0.3561 - accuracy: 0.7895 - val_loss: 0.3360 - val_accuracy: 0.7556
# Epoch 38/50
# 3/3 [==============================] - 1s 336ms/step - loss: 0.3414 - accuracy: 0.7632 - val_loss: 0.3340 - val_accuracy: 0.7778
# Epoch 39/50
# 3/3 [==============================] - 1s 336ms/step - loss: 0.3516 - accuracy: 0.7368 - val_loss: 0.3757 - val_accuracy: 0.7778
# Epoch 40/50
# 3/3 [==============================] - 1s 353ms/step - loss: 0.3220 - accuracy: 0.7632 - val_loss: 0.3876 - val_accuracy: 0.8000
# Epoch 41/50
# 3/3 [==============================] - 1s 346ms/step - loss: 0.4208 - accuracy: 0.7368 - val_loss: 0.3770 - val_accuracy: 0.7556
# Epoch 42/50
# 3/3 [==============================] - 1s 356ms/step - loss: 0.3010 - accuracy: 0.7895 - val_loss: 0.3153 - val_accuracy: 0.8222
# Epoch 43/50
# 3/3 [==============================] - 1s 372ms/step - loss: 0.3378 - accuracy: 0.7632 - val_loss: 0.3539 - val_accuracy: 0.7778
# Epoch 44/50
# 3/3 [==============================] - 1s 343ms/step - loss: 0.3343 - accuracy: 0.7895 - val_loss: 0.3469 - val_accuracy: 0.8000
# Epoch 45/50
# 3/3 [==============================] - 1s 378ms/step - loss: 0.3176 - accuracy: 0.8421 - val_loss: 0.3576 - val_accuracy: 0.7556
# Epoch 46/50
# 3/3 [==============================] - 1s 353ms/step - loss: 0.3562 - accuracy: 0.7895 - val_loss: 0.3128 - val_accuracy: 0.8000
# Epoch 47/50
# 3/3 [==============================] - 1s 382ms/step - loss: 0.3244 - accuracy: 0.8158 - val_loss: 0.3520 - val_accuracy: 0.7778
# Epoch 48/50
# 3/3 [==============================] - 1s 381ms/step - loss: 0.3522 - accuracy: 0.7778 - val_loss: 0.3301 - val_accuracy: 0.7778
# Epoch 49/50
# 3/3 [==============================] - 1s 330ms/step - loss: 0.3707 - accuracy: 0.7632 - val_loss: 0.3155 - val_accuracy: 0.8000
# Epoch 50/50
# 3/3 [==============================] - 1s 389ms/step - loss: 0.3206 - accuracy: 0.8158 - val_loss: 0.3367 - val_accuracy: 0.8000

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing import image

img=mpimg.imread('C:/Users/Satwi/Downloads/finger liveness python/finger liveness python/datasets/test/unauthenticate/download (8).jpeg')
imgplot = plt.imshow(img, interpolation='none')

test_image = image.load_img('C:/Users/Satwi/Downloads/finger liveness python/finger liveness python/datasets/test/unauthenticate/download (8).jpeg', target_size = (150, 150))


test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
print(result)

if result>=1:
    print( 'unauthenticate')
else:
    print( 'authenticate')
# Out:
# 1/1 [==============================] - 0s 70ms/step
# [[569.71515]]
# unauthenticate
